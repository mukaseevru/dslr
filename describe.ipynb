# %%
import pandas as pd
import numpy as np
from describe import *
pd.options.display.float_format = '{:.5f}'.format

# %%
df = pd.read_csv('data/dataset_train.csv')
df
# Out:
#       Index Hogwarts House First Name    Last Name    Birthday Best Hand  \
# 0         0      Ravenclaw     Tamara          Hsu  2000-03-30      Left
# 1         1      Slytherin      Erich      Paredes  1999-10-14     Right
# 2         2      Ravenclaw   Stephany        Braun  1999-11-03      Left
# 3         3     Gryffindor      Vesta    Mcmichael  2000-08-19      Left
# 4         4     Gryffindor     Gaston        Gibbs  1998-09-27      Left
# ...     ...            ...        ...          ...         ...       ...
# 1595   1595     Gryffindor       Jung        Blank  2001-09-14     Right
# 1596   1596      Slytherin     Shelli         Lock  1998-03-12      Left
# 1597   1597     Gryffindor   Benjamin  Christensen  1999-10-24     Right
# 1598   1598     Hufflepuff  Charlotte       Dillon  2001-09-21      Left
# 1599   1599     Hufflepuff      Kylie        Nowak  2000-08-21      Left
#
#       Arithmancy  Astronomy  Herbology  Defense Against the Dark Arts  \
# ...

# %%
df.describe()
# Out:
#            Index   Arithmancy  Astronomy  Herbology  \
# count 1600.00000   1566.00000 1568.00000 1567.00000
# mean   799.50000  49634.57024   39.79713    1.14102
# std    462.02453  16679.80604  520.29827    5.21968
# min      0.00000 -24370.00000 -966.74055  -10.29566
# 25%    399.75000  38511.50000 -489.55139   -4.30818
# 50%    799.50000  49013.50000  260.28945    3.46901
# 75%   1199.25000  60811.25000  524.77195    5.41918
# max   1599.00000 104956.00000 1016.21194   11.61290
#
#        Defense Against the Dark Arts  Divination  Muggle Studies  \
# count                     1569.00000  1561.00000      1565.00000
# mean                        -0.38786     3.15391      -224.58991
# std                          5.21279     4.15530       486.34484
# min                        -10.16212    -8.72700     -1086.49683
# 25%                         -5.25910     3.09900      -577.58010
# 50%                         -2.58934     4.62400      -419.16429
# ...

# %%
describe(df)
# Out:
#            Index   Arithmancy  Astronomy  Herbology  \
# count 1600.00000   1566.00000 1568.00000 1567.00000
# mean   799.50000  49634.57024   39.79713    1.14102
# std    462.02453  16679.80604  520.29827    5.21968
# min      0.00000 -24370.00000 -966.74055  -10.29566
# 25%    399.75000  53711.75000        NaN    4.93990
# 50%    799.50000  69534.50000 -625.39454    6.37029
# 75%   1199.25000  54775.50000  487.16718    5.16549
# max   1599.00000 104956.00000 1016.21194   11.61290
#
#        Defense Against the Dark Arts  Divination  Muggle Studies  \
# count                     1569.00000  1561.00000      1565.00000
# mean                        -0.38786     3.15391      -224.58991
# std                          5.21279     4.15530       486.34484
# min                        -10.16212    -8.72700     -1086.49683
# 25%                         -6.24599     5.87150             NaN
# 50%                              NaN     1.75000      -906.93476
# ...
